# %% [markdown]
# # Pruebas para proyecto speaker diarization
#
# Parte 1: Se analizan todos los audios a nivel estadístico.
#
# Direcciones de archivos: /mnt/f/audio_cortes/segmentos_estadistica/estadistica*

# %%
# %run /home/roberto/wave_SpeakerDiarization/estadisticas_audios.py /mnt/f/audio_cortes/segmentos_estadistica/estadistica*
# Out:
# Archivo:  /mnt/f/audio_cortes/segmentos_estadistica/estadistica_20200312_desayunos_parte1.segments
#
# Cantidad de hablantes:  9
#
# Tiempo promedio de intervención:
#  {'SpeakerA_anuncioUCR_M': 30.0, 'SpeakerB_anuncioUCR_H': 10.200000000000045, 'SpeakerC_presentadora1_M': 33.413333333333334, 'SpeakerD_invitado1_H': 92.9, 'SpeakerE_presentador2_H': 26.875, 'SpeakerF_anuncio1_H': 5.0499999999999545, 'SpeakerG_anuncio1_M': 1.566666666666606, 'SpeakerH_anuncio2_M': 7.149999999999977, 'SpeakerI_anuncio3_M': 32.299999999999955}
#
# Tiempo total del habla:
#  {'SpeakerA_anuncioUCR_M': 30.0, 'SpeakerB_anuncioUCR_H': 30.600000000000136, 'SpeakerC_presentadora1_M': 501.20000000000005, 'SpeakerD_invitado1_H': 929.0, 'SpeakerE_presentador2_H': 215.0, 'SpeakerF_anuncio1_H': 20.199999999999818, 'SpeakerG_anuncio1_M': 4.699999999999818, 'SpeakerH_anuncio2_M': 14.299999999999955, 'SpeakerI_anuncio3_M': 32.299999999999955}
#
# 9 Hombres  4 :  67.22556687109662 Mujeres  5 :  32.77443312890338
#
# ...

# %%
# %run /home/roberto/wave_SpeakerDiarization/estadisticas_audios.py /mnt/f/audio_cortes/segmentos_estadistica/marvin/estadistica*
# Out:
# Archivo:  /mnt/f/audio_cortes/segmentos_estadistica/marvin/estadistica_20200316_Desayunos_parte1.segments
#
# Cantidad de hablantes:  16
#
# Tiempo promedio de intervención:
#  {'SpeakerA_intro_M': 25.75, 'SpeakerB_presentador1_H': 27.15555555555555, 'SpeakerC_presentadora2_M': 51.449999999999996, 'SpeakerD_invitada_M': 80.35666666666667, 'SpeakerE_musicaanuncio1': 4.75, 'SpeakerF_presentadoranuncio': 2.0, 'SpeakerG_vozanuncio1': 6.0, 'SpeakerH_vozanuncio2': 12.0, 'SpeakerI_presentadoraanuncio': 9.5, 'SpeakerJ_vozanuncio3': 14.0, 'SpeakerK_vozanuncio4': 15.0, 'SpeakerL_vozanuncio5': 15.0, 'SpeakerM_musicaanuncio2': 3.0, 'SpeakerN_presentadoranuncio2': 6.0, 'SpeakerO_presentadoraanuncio2': 1.6666666666666667, 'SpeakerP_segmentoexplicativo': 21.0}
#
# Tiempo total del habla:
# ...

# %% [markdown]
# ## Audio 1

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte1.wav --num 9
# Out:
# 84.3	45.3

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py evaluateSpeakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte1.wav --num 9
# Out:
# usage: audioAnalysis.py [-h]  ...
# audioAnalysis.py: error: argument : invalid choice: 'evaluateSpeakerDiarization' (choose from 'dirMp3toWav', 'dirWavResample', 'featureExtractionFile', 'beatExtraction', 'featureExtractionDir', 'featureVisualization', 'fileSpectrogram', 'fileChromagram', 'trainClassifier', 'trainRegression', 'classifyFile', 'trainHMMsegmenter_fromfile', 'trainHMMsegmenter_fromdir', 'segmentClassifyFile', 'segmentClassifyFileHMM', 'segmentationEvaluation', 'regressionFile', 'classifyFolder', 'regressionFolder', 'silenceRemoval', 'speakerDiarization', 'speakerDiarizationScriptEval', 'thumbnail')
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/argparse.py", line 1812, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "/usr/lib/python3.8/argparse.py", line 2000, in _parse_known_args
# ...

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte1.wav --num 0
# Out:
# 75.2	92.7

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte1.wav -n 9 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 87.6	46.0

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte1.wav -n 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 77.7	95.4

# %% [markdown]
# ## ------------------------------------------------------------------------------------------------

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte2.wav --num 15
# Out:
# 84.7	46.2

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte2.wav --num 0
# Out:
# 74.9	97.7

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte2.wav --num 15 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 164 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 87.1	33.4

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200312/20200312_desayunos_parte2.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 164 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 74.8	97.2

# %% [markdown]
# ## Audio 2

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte1.wav --num 14
# Out:
# 83.2	46.6

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte1.wav --num 0
# Out:
# 66.4	79.5

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte1.wav --num 14 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 86.8	30.2

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte1.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 66.8	97.7

# %% [markdown]
# ## --------------------------------------------------------------------------------

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte2.wav --num 10
# Out:
# 79.8	52.9

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte2.wav --num 0
# Out:
# 59.6	94.4

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte2.wav --num 10 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 163 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 85.4	48.3

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200313/20200313_Desayunos_parte2.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 163 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 70.3	97.3

# %% [markdown]
# ## Audio 3

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte1.wav --num 5
# Out:
# 82.6	71.0

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte1.wav --num 0
# Out:
# 65.4	97.6

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte1.wav --num 5 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 94.8	74.7

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte1.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 65.4	97.7

# %% [markdown]
# ## ------------------------------------------------------------------------

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte2.wav --num 5
# Out:
# 82.5	72.4

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte2.wav --num 0
# Out:
# 74.1	98.5

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte2.wav --num 5 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 170 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 92.3	74.2

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200421/20200421_desayunos_parte2.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 170 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 74.3	98.9

# %% [markdown]
# ## Audio 4

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte1.wav --num 4
# Out:
# 83.4	64.4

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte1.wav --num 0
# Out:
# 81.8	95.5

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte1.wav --num 4 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 97.2	97.2

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte1.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 82.9	95.5

# %% [markdown]
# ## ----------------------------------------------------------------------

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte2.wav --num 5
# Out:
# 80.2	56.8

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte2.wav --num 5 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 170 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 92.4	63.5

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte2.wav --num 0
# Out:
# 74.2	87.5

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/20200422/20200422_desayunos_parte2.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 170 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 79.6	88.0

# %% [markdown]
# ## Audio 5

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte1.wav --num 3
# Out:
# 98.0	58.1

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte1.wav --num 3 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 99.2	57.8

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte1.wav --num 0
# Out:
# 98.0	26.9

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte1.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 181 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 99.2	57.8

# %% [markdown]
# ## --------------------------------------------------------------------------------------

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte2.wav --num 2
# Out:
# 97.5	66.0

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte2.wav --num 2 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 189 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 97.5	52.4

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte2.wav --num 0
# Out:
# 97.5	48.4

# %%
# %run ~/pyAudioAnalysis/pyAudioAnalysis/audioAnalysis.py speakerDiarization -i /mnt/f/audio_cortes/2desayunos/desayunos_parte2.wav --num 0 --flsd
# Out:
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:461: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 189 - 1) = 26 components.
#   warnings.warn(
# /home/roberto/.local/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# 100.0	54.6
